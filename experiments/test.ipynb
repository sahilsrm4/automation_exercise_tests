# %%
def add(*a,b):
 print(a)
 print(b)

# %%
add(2,3,4,5,6,7,8,b=9)
# Out:
# (2, 3, 4, 5, 6, 7, 8)
# 9

# %%
__file__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 __file__
#
# NameError: name '__file__' is not defined
